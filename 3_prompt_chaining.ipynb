# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str  
    evaluate:str

# %%
llm = ChatGoogleGenerativeAI(model="gemini-flash-latest")

# %%
def create_outline(state: BlogState) -> BlogState:
    title=state['title']
    prompt=f"Create a detailed outline for a blog post with the title: {title}"
    outline=llm.invoke(prompt).content
    state['outline']=outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    outline=state['outline']
    prompt=f"Write a detailed blog post based on the following outline:\n{outline}"
    content=llm.invoke(prompt).content
    state['content']=content
    return state

# %%
def evaluate_blog(state: BlogState) -> BlogState:
    outline=state['outline']
    prompt=f"Evaluate the following blog post for clarity, engagement, and informativeness:\n{outline}\nProvide feedback and a score out of 10."
    evaluation=llm.invoke(prompt).content
    state['evaluate']=evaluation
    return state

# %%
graph=StateGraph(BlogState)
# add  nodes
graph.add_node("create_outline",create_outline)
graph.add_node("create_blog",create_blog)
graph.add_node("evaluate_blog",evaluate_blog)

# add edges
graph.add_edge(START,"create_outline")
graph.add_edge("create_outline","create_blog")
graph.add_edge("create_blog","evaluate_blog")
graph.add_edge("evaluate_blog",END)
workflow=graph.compile()

# %%
inital_state={"title":"The Future of AI in Everyday Life"}
final_state=workflow.invoke(inital_state)
print(final_state)
# Out:
# {'title': 'The Future of AI in Everyday Life', 'outline': '## Detailed Outline: The Future of AI in Everyday Life\n\n**Title:** The Future of AI in Everyday Life\n\n**Target Audience:** General readers interested in technology, futurism, and practical applications of AI.\n\n**Goal:** To explore the near-future integration of AI across various domestic and personal domains, moving beyond current smart assistants, and to discuss the resulting societal shifts (both exciting and cautionary).\n\n---\n\n### I. Introduction (The AI Tipping Point)\n\n**A. Hook (The "Invisible" AI):**\n*   Start with a relatable scenario: AI is already managing your commute, filtering your email, and suggesting your next binge-watch.\n*   *Future Hook:* Imagine an AI proactively managing your health or designing your dinner menu based on your microbiome data.\n\n**B. Defining the Scope:**\n*   Briefly distinguish current AI (Reactive/Narrow) from future AI (Proactive/Generative/Integrated).\n*   Focus on the next 5–10 years—practical, widespread adoption, not pure science fiction.\n\n**C. Thesis Statement:**\n*   The next decade will see AI move from a helpful tool to an integrated, predictive life partner, fundamentally reshaping how we manage our homes, health, work, and leisure.\n\n---\n\n### II. AI in the Home: The Hyper-Intelligent Ecosystem\n\n**A. The Truly Smart Home (Beyond Voice Commands):**\n*   **Current State:** "Turn on the lights."\n*   **Future State:** The home OS anticipates needs (e.g., adjusting temperature based on predicted energy prices and occupants\' mood/activity).\n*   **Predictive Maintenance:** AI monitoring appliance health, ordering parts, and scheduling repairs *before* failure occurs.\n\n**B. Domestic Robotics and Automation:**\n*   **General Purpose Robots (GPRs):** Discuss the rise of practical, multi-tasking domestic robots (e.g., advanced cleaning, basic cooking assistance, fetching).\n*   **AI-Powered Personal Chefs:** Systems that manage inventory, optimize nutrition, and execute complex meal preparations tailored to dietary needs and preferences.\n\n**C. Personalized Learning Environments:**\n*   AI tutors that adapt curriculum in real-time to a child\'s learning pace, emotional state, and interests.\n\n---\n\n### III. AI and Personalized Wellness\n\n**A. Hyper-Individualized Health Management:**\n*   **Wearables 2.0:** Devices continuously monitoring biomarkers (blood sugar, stress hormones, sleep quality) and feeding data to a centralized AI health coach.\n*   **Predictive Diagnostics:** AI identifying the early onset of illness (e.g., viral infection, chronic condition flare-ups) days before symptoms appear.\n*   **Mental Health Companions:** AI providing personalized, non-judgmental support, mindfulness exercises, and tracking emotional patterns for early intervention.\n\n**B. Drug and Supplement Optimization:**\n*   AI recommending precise dosages and combinations of supplements or medications based on real-time physiological data and genetic makeup.\n\n---\n\n### IV. AI in the Workplace and Daily Administration\n\n**A. The Shift from Automation to Augmentation:**\n*   AI taking over tedious, repetitive tasks (scheduling, data entry, email filtering/drafting) across all sectors.\n*   **The AI Co-Worker:** AI acting as a brainstorming partner, synthesizing complex information, and drafting high-quality first versions of documents (legal briefs, code, reports).\n\n**B. Seamless Financial Management:**\n*   AI financial advisors managing budgets, optimizing investments, and automatically handling taxes with minimal human input.\n\n**C. Navigating the Physical World (AI Mobility):**\n*   Widespread adoption of autonomous vehicles, reducing traffic congestion and freeing up commute time for productivity or leisure.\n*   AI optimizing public transit and delivery logistics.\n\n---\n\n### V. Societal Implications and Ethical Considerations (The Trade-Offs)\n\n**A. The Privacy Paradox:**\n*   The necessity of massive ...

# %%
print(final_state['outline'])
# Out:
# [{'type': 'text', 'text': 'This outline is designed for a comprehensive, engaging blog post of approximately 1,500–2,000 words, focusing on practical, near-future applications rather than purely theoretical science fiction.\n\n---\n\n# Detailed Blog Post Outline: The Future of AI in Everyday Life\n\n## I. Introduction (The Invisible Revolution)\n\n### A. Catchy Hook:\n*   Start with a relatable scenario: AI isn\'t just about robots; it’s the intelligence behind your seamless streaming recommendation, your optimized commute, and your smart thermostat.\n*   **Thesis:** AI is moving from being a novelty tool (like Siri or Alexa) to becoming ambient, proactive, and deeply integrated into the fundamental structures of daily life, making decisions before we even realize we need them.\n\n### B. Defining the Scope:\n*   Briefly distinguish between current AI (Reactive) and future AI (Proactive/Ambient Intelligence).\n*   Focus on the next 5-10 years: practical, accessible technologies.\n\n### C. Reader Takeaway Promise:\n*   What major shifts should the reader prepare for in their home, health, and work life?\n\n---\n\n## II. The Intelligent Home: Ambient Automation\n\nThe shift from "Smart Homes" (requiring explicit commands) to "Intelligent Homes" (anticipating needs).\n\n### A. Predictive Energy Management and Optimization\n*   **1. Hyper-Personalized Comfort:** AI learns individual family schedules, preferred temperatures, and humidity levels, dynamically adjusting HVAC before people arrive home.\n*   **2. Resource Conservation:** Using real-time grid data and weather forecasts to minimize electricity use during peak hours without sacrificing comfort.\n\n### B. Proactive Security and Monitoring\n*   **1. Contextual Recognition:** AI moving beyond simple facial recognition to recognizing *context* (e.g., distinguishing a delivery person from an unauthorized visitor, or a pet’s movement from an intruder).\n*   **2. Maintenance Alerts:** AI sensors monitoring infrastructure (plumbing, wiring) for subtle failures, alerting homeowners *before* a pipe bursts or a fuse blows.\n\n### C. The Kitchen as a Nutritional Assistant\n*   AI-powered smart appliances managing inventory, suggesting recipes based on dietary goals, and even ordering replacement groceries automatically.\n\n---\n\n## III. AI as Your Personal Chief of Staff (Work and Productivity)\n\nAI eliminating administrative burden and augmenting cognitive tasks.\n\n### A. The Automated Administrative Assistant\n*   **1. Calendar and Scheduling Mastery:** AI systems that don’t just book meetings, but negotiate context, time zones, and priority conflicts with other AI systems autonomously.\n*   **2. Inbox Triage and Drafting:** Moving beyond spam filters to actively drafting appropriate responses to non-critical emails, flagging priority clients, and summarizing long communication threads.\n\n### B. Cognitive Copilots\n*   **1. Data Synthesis:** Tools that instantly summarize complex reports, white papers, or financial data into actionable bullet points.\n*   **2. Idea Generation and Augmentation:** Using generative AI models (like advanced GPTs) as thought partners for brainstorming, strategy development, and refining complex arguments.\n\n### C. Eliminating Friction in Collaboration\n*   AI transcription and summarization of meetings, coupled with automatic distribution of action items to relevant team members.\n\n---\n\n## IV. Health, Wellness, and the Personalized AI Doctor\n\nAI shifting healthcare from reactive treatment to proactive, preventative management.\n\n### A. Continuous, Non-Invasive Diagnostics\n*   **1. Wearables 2.0:** Devices that monitor dozens of biomarkers (blood glucose, hydration, stress hormones) passively through smart clothing or skin patches.\n*   **2. Early Detection:** AI analyzing subtle changes in voice patterns, typing speed, or sleep quality to predict the onset of colds, depression, or chronic conditions weeks in advance.\n\n### B. Hyper-Personaliz ...

# %%
print(final_state['content'])
# Out:
# [{'type': 'text', 'text': '# The Invisible Revolution: Why AI is About to Disappear into Your Daily Life\n\nYou didn’t command it. You didn’t even think about it. Yet, the moment you stepped into your home after a long commute, the air conditioning subtly adjusted to your preferred humidity level, the lights dimmed to your optimal focus setting, and your fridge had already ordered the single ingredient you were running low on.\n\nThis isn’t science fiction. This is the future of Artificial Intelligence—and it’s already here, just wearing a very effective camouflage.\n\nFor years, our relationship with AI has been reactive. We shouted commands at smart speakers, manually trained our recommendation algorithms, or explicitly used tools like Siri or Alexa. AI was a novelty tool, an on-demand servant.\n\nThat era is ending.\n\n**The central thesis of the next decade is this:** AI is moving from being a novelty tool to becoming **ambient, proactive, and deeply integrated** into the fundamental structures of daily life, making decisions and managing complexity before we even realize we need them.\n\nWe are witnessing the invisible revolution.\n\nIn the next five to ten years, the most powerful AI won\'t be the one you talk to, but the one you never notice. It will be the intelligence system streamlining your health, optimizing your career, and managing the delicate balance of your home’s ecosystem.\n\nWhat major shifts should you prepare for in your home, health, and work life? Let’s explore the practical realities of the Ambient Intelligence era.\n\n---\n\n## II. The Intelligent Home: Ambient Automation\n\nThe "Smart Home" required explicit commands; the "Intelligent Home" anticipates needs. This transition fundamentally changes our relationship with our living spaces, turning them into responsive, self-managing entities.\n\n### A. Predictive Energy Management and Optimization\n\nThe battle against high utility bills and resource waste will be won by AI that understands context far better than any human schedule.\n\n#### 1. Hyper-Personalized Comfort\nFuture HVAC systems won’t just rely on a preset schedule. They will use data from wearables, calendar inputs, and real-time traffic updates to predict when individuals or family members will arrive home. AI will learn individual preferences—not just temperatures, but specific humidity levels and air quality needs—and dynamically adjust the environment up to an hour in advance, ensuring peak comfort the moment the door opens.\n\n#### 2. Resource Conservation\nThis personalization is coupled with profound efficiency. AI will use real-time data from the energy grid and hyper-local weather forecasts to minimize electricity use during peak pricing hours. For instance, if a heatwave is predicted, the AI might pre-cool the house using inexpensive nighttime power, allowing the home to coast through the afternoon peak without sacrificing comfort, resulting in significant savings and a reduced carbon footprint.\n\n### B. Proactive Security and Monitoring\n\nSecurity shifts from merely alerting us to threats to understanding *intent* and predicting infrastructure failures.\n\n#### 1. Contextual Recognition\nAI-powered security cameras are moving beyond simple facial recognition. They are learning to recognize **context**. This means distinguishing between a delivery person standing momentarily by the door, a pet triggering a sensor, and an unauthorized visitor loitering with suspicious intent. The system understands the difference between a child playing in the yard and a potential intruder, drastically reducing false alarms and improving response times.\n\n#### 2. Maintenance Alerts\nPerhaps the most underrated application of AI in the home is infrastructure monitoring. Tiny, affordable sensors embedded in plumbing, wiring, and foundations will constantly monitor vibration, humidity, and electrical resistance. The AI analyzes subtle deviations—a slight drop in water pressure, an unusual hum in t ...

# %%
print(final_state['evaluate'])
# Out:
# This outline is exceptionally strong, well-structured, and highly effective in meeting its stated goals. It successfully balances excitement about future technology with necessary critical examination.
#
# Here is a detailed evaluation based on the requested criteria:
#
# ---
#
# ## Evaluation of the Blog Post Outline
#
# ### 1. Clarity (Score: 5/5)
#
# The clarity of this outline is outstanding.
#
# *   **Logical Flow:** The structure follows a natural, compelling progression: Present state → Future application (Home, Health, Work) → Societal consequences → Conclusion. This makes the argument easy to follow and prevents the reader from getting lost in complex technological concepts.
# *   **Defined Scope:** The introduction clearly distinguishes between current "Reactive/Narrow" AI and future "Proactive/Integrated" AI, setting realistic expectations for the "next 5–10 years."
# *   **Specific Examples:** The use of "Current State" vs. "Future State" examples (e.g., Section II.A) is a powerful tool for clarity. Topics like "Predictive Maintenance" and "Hyper-Individualized Health Management" are clearly defined by their supporting bullet points.
# *   **Strong Thesis:** The thesis statement is clear, ambitious, and successfully frames the entire subsequent discussion.
#
# ### 2. Engagement (Score: 4.5/5)
#
# The outline is designed to be highly engaging, targeting the reader’s personal life and future anxieties.
#
# *   **Relatable Hook:** Starting with the "Invisible AI" that already manages the commute and streaming habits immediately grounds the topic in the reader’s reality.
# *   **Aspirational Content:** Sections on personalized wellness (AI health coach, predictive diagnostics) and the hyper-intelligent home tap into universal desires for convenience and better health. These are not abstract concepts; they are immediately desirable.
# *   **Critical Tension:** Section V (Societal Implications) is crucial for engagement. By addressing the "Privacy Paradox" and "Skill Erosion," the outline moves beyond a simple technology showcase and invites the reader to participate in a serious, ongoing debate.
# *   **Strong Conclusion:** The Call to Action encourages critical thought and action, leaving the reader with a sense of agency rather than passive acceptance.
#
# **Minor Area for Improvement:** While the content is engaging, the shift from Section IV (Work) to Section V (Ethics) might feel slightly abrupt. A minor transitional sentence could bridge the excitement of augmentation with the gravity of the trade-offs.
#
# ### 3. Informativeness (Score: 5/5)
#
# The outline is rich with detail and covers the topic comprehensively across multiple domains.
#
# *   **Breadth of Coverage:** The post doesn't just focus on smart speakers; it covers Home, Health, Finance, Mobility, Education, and Labor. This provides a holistic view of AI integration.
# *   **Depth of Concepts:** It introduces complex, high-value concepts without resorting to jargon. Examples include:
#     *   General Purpose Robots (GPRs)
#     *   The distinction between Automation and Augmentation
#     *   Wearables 2.0 (continuous biomarker monitoring)
#     *   Algorithmic bias
# *   **Focus on the "How":** It informs the reader not just about *what* AI will do (e.g., manage money), but *how* it will do it (optimizing investments, handling taxes automatically).
# *   **Ethical Insight:** Section V provides essential information regarding the trade-offs (data necessity, labor disruption), making the piece valuable beyond mere technological prediction.
#
# ---
#
# ## Overall Assessment and Score
#
# This outline is a blueprint for an excellent, well-balanced, and highly readable blog post. It successfully navigates complex technological concepts while keeping the focus on practical, human-centered applications and implications. It is clear, thought-provoking, and covers the necessary breadth and depth to fully inform the target audience.
#
# The structure ensures that the final piece will be easy to write, easy to read, and highly shareable due to its blend of futurism and critical ethics.
#
# **Overall Score: 9.5/10**
